# %% [markdown]
# <a href="https://colab.research.google.com/github/mpagas/MIS2800/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("mis is best")
